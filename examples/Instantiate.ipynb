# %%
import Pkg;
Pkg.activate("/sps/nemo/scratch/mpetro/Sensitivity_training/")
Pkg.instantiate()
Pkg.precompile()
# Out:
#   Activating project at `/sps/nemo/scratch/mpetro/Sensitivity_training`
# Precompiling project...
#   ✓ Pango_jll
#   ✓ PrettyTables
#   ✓ FFMPEG
#   ✓ Cairo
#   ✓ DataFrames
#   ✓ BinnedModels
#   ✓ DataFramesMeta
#   ✓ Makie
#   ✓ DomainSets → DomainSetsMakieExt
#   ✓ Measurements → MeasurementsMakieExt
#   ✓ FHist → FHistMakieExt
#   ✓ CairoMakie
#   ✓ UnROOT
#   ✓ SNSensitivityEstimate
#   14 dependencies successfully precompiled in 1352 seconds. 415 already precompiled.
#   1 dependency had output during precompilation:
# ┌ SNSensitivityEstimate
# │  ┌ Warning: AES-acceleration instructions have not been detected, so the related RNGs (AESNI and ARS) are not available.
# │  └ @ Random123 /sps/nemo/scratch/mpetro/PROGRAMS/.julia_sym/packages/Random123/QDdNH/src/Random123.jl:107
# └
