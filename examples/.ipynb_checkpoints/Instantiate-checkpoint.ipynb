# %%
import Pkg;
Pkg.activate("/sps/nemo/scratch/mpetro/Sensitivity_training/")
Pkg.instantiate()
# Out:
#   Activating project at `/sps/nemo/scratch/mpetro/Sensitivity_training`
# Precompiling project...
#   ✓ IntervalSets → IntervalSetsRecipesBaseExt
#   ✓ CodecXz
#   ✓ Measurements → MeasurementsRecipesBaseExt
#   ✓ Quadmath → QuadmathSpecialFunctionsExt
#   ✓ ChunkCodecLibZstd
#   ✓ LogarithmicNumbers → LogarithmicNumbersForwardDiffExt
#   ✓ FFMPEG
#   ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ Accessors → StaticArraysExt
#   ✓ Unitful → ForwardDiffExt
#   ✓ XXHashNative
#   ✓ Interpolations → InterpolationsForwardDiffExt
#   ✓ Distributions → DistributionsTestExt
#   ✓ Roots → RootsForwardDiffExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#   ✓ DoubleFloats
#   ✓ AutoDiffOperators → AutoDiffOperatorsStaticArraysExt
#   ✓ Distributions → DistributionsDensityInterfaceExt
#   ✓ ForwardDiffPullbacks
#   ✓ MeasureBase
#   ✓ EmpiricalDistributions
#   ✓ NearestNeighbors
# ...
