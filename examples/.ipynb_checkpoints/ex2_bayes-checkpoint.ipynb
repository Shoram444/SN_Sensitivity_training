# %% [markdown]
# # Bayesian Sensitivity Estimate Example
#
# This example shows how to calculate the **Bayesian sensitivity** for a given signal process using the `SNSensitivityEstimate` package.
#
# Where the first example (`ex1`) only looked at the *expected background counts*, here we go a step further: we build a full Bayesian model of signal + background, fit it to a simulated ("pseudo-") dataset, and from the posterior we derive a **sensitivity** — the half-life that the experiment could realistically probe given the expected background level, exposure, and signal efficiency.

# %%
import Pkg;
Pkg.activate("/sps/nemo/scratch/mpetro/Sensitivity_training/")
using SNSensitivityEstimate, UnROOT, FHist, CairoMakie, CSV, DataFramesMeta
using Random, LinearAlgebra, Statistics, Distributions, BAT, BinnedModels, StatsBase, DensityInterface, IntervalSets, SpecialFunctions, ValueShapes
using Distributions
# Out:
#   Activating project at `/sps/nemo/scratch/mpetro/Sensitivity_training`
# [ Info: Precompiling SNSensitivityEstimate [4337d2dd-53cf-40a5-bc43-6e7cc5722bd2]
# ┌ Warning: Module PrecompileTools with build ID fafbfcfd-e880-2b99-000f-58856e04c9e8 is missing from the cache.
# │ This may mean PrecompileTools [aea7be01-6a6a-4083-8856-8a6e6704d82a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing SNSensitivityEstimate [4337d2dd-53cf-40a5-bc43-6e7cc5722bd2].
# [ Info: Precompiling DataFramesMeta [1313f7d8-7da2-5740-9ea0-a2ca25f37964]
# ┌ Warning: Module PrecompileTools with build ID fafbfcfd-e880-2b99-000f-58856e04c9e8 is missing from the cache.
# │ This may mean PrecompileTools [aea7be01-6a6a-4083-8856-8a6e6704d82a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing DataFramesMeta [1313f7d8-7da2-5740-9ea0-a2ca25f37964].
# [ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# ┌ Warning: Module PrecompileTools with build ID fafbfcfd-e880-2b99-000f-58856e04c9e8 is missing from the cache.
# │ This may mean PrecompileTools [aea7be01-6a6a-4083-8856-8a6e6704d82a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0].
# [ Info: Precompiling PrettyTables [08abe8d2-0d0c-5749-adfa-8a2ac140af0d]
# ┌ Warning: Module PrecompileTools with build ID fafbfcfd-e880-2b99-000f-58856e04c9e8 is missing from the cache.
# │ This may mean PrecompileTools [aea7be01-6a6a-4083-8856-8a6e6704d82a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing PrettyTables [08abe8d2-0d0c-5749-adfa-8a2ac140af0d].
# [ Info: Precompiling ParsersExt [f526588d-e68b-5dc5-a62e-ff9f36e48b1a]
# ┌ Warning: Module Parsers with build ID fafbfcfd-9d0f-7f4c-000f-5885fe1fd631 is missing from the cache.
# │ This may mean Parsers [69de0a69-1ddd-5017-9359-2bf0b02dc9f0] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing ParsersExt [f526588d-e68b-5dc5-a62e-ff9f36e48b1a].
# [ Info: Precompiling UnROOT [3cd96dde-e98d-4713-81e9-a4a1b0235ce9]
# ┌ Warning: Module JLLWrappers with build ID fafbfcfd-fd0a-b190-000f-58855e89d918 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing UnROOT [3cd96dde-e98d-4713-81e9-a4a1b0235ce9].
# [ Info: Precompiling CodecLz4 [5ba52731-8f18-5e0d-9241-30f10d1ec561]
# ┌ Warning: Module JLLWrappers with build ID fafbfcfd-fd0a-b190-000f-58855e89d918 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing CodecLz4 [5ba52731-8f18-5e0d-9241-30f10d1ec561].
# [ Info: Precompiling Lz4_jll [5ced341a-0733-55b8-9ab6-a4889d929147]
# ┌ Warning: Module JLLWrappers with build ID fafbfcfd-fd0a-b190-000f-58855e89d918 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing
does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing MLDataDevices [7e8f7934-dd98-4c1a-8fe8-92b47a384d40].
# [ Info: Precompiling ChainRulesCoreExt [8ccf546c-b5ad-5491-b9b6-b62e2a4db961]
# ┌ Warning: Module MLDataDevices with build ID ffffffff-ffff-ffff-000f-649d71519244 is missing from the cache.
# │ This may mean MLDataDevices [7e8f7934-dd98-4c1a-8fe8-92b47a384d40] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing ChainRulesCoreExt [8ccf546c-b5ad-5491-b9b6-b62e2a4db961].
# [ Info: Precompiling FillArraysExt [040fa5a8-9292-56e1-9422-e9ee4eee16cd]
# ┌ Warning: Module MLDataDevices with build ID ffffffff-ffff-ffff-000f-649d71519244 is missing from the cache.
# │ This may mean MLDataDevices [7e8f7934-dd98-4c1a-8fe8-92b47a384d40] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing FillArraysExt [040fa5a8-9292-56e1-9422-e9ee4eee16cd].
# [ Info: Precompiling SparseArraysExt [d59e0577-78a2-56be-b22d-01c326f52333]
# ┌ Warning: Module MLDataDevices with build ID ffffffff-ffff-ffff-000f-649d71519244 is missing from the cache.
# │ This may mean MLDataDevices [7e8f7934-dd98-4c1a-8fe8-92b47a384d40] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing SparseArraysExt [d59e0577-78a2-56be-b22d-01c326f52333].
# [ Info: Precompiling ChainRulesExt [f152a86e-e60b-5ef3-ac8e-cdcef9fc354e]
# ┌ Warning: Module MLDataDevices with build ID ffffffff-ffff-ffff-000f-649d71519244 is missing from the cache.
# │ This may mean MLDataDevices [7e8f7934-dd98-4c1a-8fe8-92b47a384d40] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing ChainRulesExt [f152a86e-e60b-5ef3-ac8e-cdcef9fc354e].
# [ Info: Precompiling MeasureBase [fa1605e6-acd5-459c-a1e6-7e635759db14]
# ┌ Warning: Module Static with build ID ffffffff-ffff-ffff-000f-64977864e96a is missing from the cache.
# │ This may mean Static [aedffcd0-7271-4cad-89d0-dc628f76c6d3] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing MeasureBase [fa1605e6-acd5-459c-a1e6-7e635759db14].
# [ Info: Precompiling LogarithmicNumbersForwardDiffExt [93b47b7c-0f02-5088-90d7-55f527d3c7c9]
# ┌ Warning: Module ForwardDiff with build ID ffffffff-ffff-ffff-000f-6495e7910397 is missing from the cache.
# │ This may mean ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing LogarithmicNumbersForwardDiffExt [93b47b7c-0f02-5088-90d7-55f527d3c7c9].
# [ Info: Precompiling DomainSets [5b8099bc-c8ec-5219-889f-1d9e522a28bf]
# ┌ Warning: Module StaticArrays with build ID ffffffff-ffff-ffff-000f-648047676183 is missing from the cache.
# │ This may mean StaticArrays [90137ffa-7385-5640-81b9-e52037218182] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing DomainSets [5b8099bc-c8ec-5219-889f-1d9e522a28bf].
# [ Info: Precompiling FunctionMaps [a85aefff-f8ca-4649-a888-c8e5398bc76c]
# ┌ Warning: Module StaticArrays with build ID ffffffff-ffff-ffff-000f-648047676183 is missing from the cache.
# │ This may mean StaticArrays [90137ffa-7385-5640-81b9-e52037218182] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing FunctionMaps [a85aefff-f8ca-4649-a888-c8e5398bc76c].
# [ Info: Precompiling DomainSetsRandomExt [2ccfe529-ffd9-59a6-ab14-fd6001c306d6]
# ┌ Warning: Module DomainSets with build ID ffffffff-ffff-ffff-000f-64a1aae9e172 is missing from the cache.
# │ This may mean DomainSets [5b8099bc-c8ec-5219-889f-1d9e522a28bf] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Import
does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing IntervalArithmeticDiffRulesExt [86439bda-9ede-5c22-99a0-f82df582fb22].
# [ Info: Precompiling IntervalArithmeticIntervalSetsExt [fe1c01f3-e48c-5d10-9a22-1f3e4b1804eb]
# ┌ Warning: Module IntervalArithmetic with build ID ffffffff-ffff-ffff-000f-64bd63eb3318 is missing from the cache.
# │ This may mean IntervalArithmetic [d1acc4aa-44c8-5952-acd4-ba5d80a2a253] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing IntervalArithmeticIntervalSetsExt [fe1c01f3-e48c-5d10-9a22-1f3e4b1804eb].
# [ Info: Precompiling IntervalArithmeticLinearAlgebraExt [2191e3cb-bfc0-5415-be28-d82ab1f2c0a4]
# ┌ Warning: Module IntervalArithmetic with build ID ffffffff-ffff-ffff-000f-64bd63eb3318 is missing from the cache.
# │ This may mean IntervalArithmetic [d1acc4aa-44c8-5952-acd4-ba5d80a2a253] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing IntervalArithmeticLinearAlgebraExt [2191e3cb-bfc0-5415-be28-d82ab1f2c0a4].
# [ Info: Precompiling OpenBLASConsistentFPCSR_jll [6cdc7f73-28fd-5e50-80fb-958a8875b1af]
# ┌ Warning: Module JLLWrappers with build ID fafbfcfd-fd0a-b190-000f-58855e89d918 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing OpenBLASConsistentFPCSR_jll [6cdc7f73-28fd-5e50-80fb-958a8875b1af].
# [ Info: Precompiling IntervalArithmeticIrrationalConstantsExt [e6d9325f-77ee-521a-95dc-c17f2c87b687]
# ┌ Warning: Module IntervalArithmetic with build ID ffffffff-ffff-ffff-000f-64bd63eb3318 is missing from the cache.
# │ This may mean IntervalArithmetic [d1acc4aa-44c8-5952-acd4-ba5d80a2a253] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing IntervalArithmeticIrrationalConstantsExt [e6d9325f-77ee-521a-95dc-c17f2c87b687].
# [ Info: Precompiling IntervalArithmeticSparseArraysExt [7d512a68-f907-5f80-bfe1-b09a08cec04b]
# ┌ Warning: Module IntervalArithmetic with build ID ffffffff-ffff-ffff-000f-64bd63eb3318 is missing from the cache.
# │ This may mean IntervalArithmetic [d1acc4aa-44c8-5952-acd4-ba5d80a2a253] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing IntervalArithmeticSparseArraysExt [7d512a68-f907-5f80-bfe1-b09a08cec04b].
# [ Info: Precompiling ImageBase [c817782e-172a-44cc-b673-b171935fbb9e]
# ┌ Warning: Module PrecompileTools with build ID fafbfcfd-e880-2b99-000f-58856e04c9e8 is missing from the cache.
# │ This may mean PrecompileTools [aea7be01-6a6a-4083-8856-8a6e6704d82a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing ImageBase [c817782e-172a-44cc-b673-b171935fbb9e].
# [ Info: Precompiling ImageCore [a09fc81d-aa75-5fe9-8630-4744c3626534]
# ┌ Warning: Module PrecompileTools with build ID fafbfcfd-e880-2b99-000f-58856e04c9e8 is missing from the cache.
# │ This may mean PrecompileTools [aea7be01-6a6a-4083-8856-8a6e6704d82a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing ImageCore [a09fc81d-aa75-5fe9-8630-4744c3626534].
# [ Info: Precompiling PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883]
# ┌ Warning: Module ImageCore with build ID ffffffff-ffff-ffff-000f-64c3e4b05d68 is missing from the cache.
# │ This may mean ImageCore [a09fc81d-aa75-5fe9-8630-4744c3626534] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883].
# [ Info: Precompiling FHistMakieExt [4aea7262-834d-58a9-8449-4904e521f200]
# ┌ Warning: Module Makie with build ID ffffffff-ffff-ffff-000f-64a9c18a20b3 is missing from the cache.
# │ This may mean Makie [ee78f7c6-11fb-53f2-987a-cfe4a2b5a57a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing FHistMakieExt [4aea7262-834d-58a9-8449-4904e521f200].
# [ Info: Precompiling MeasurementsMakieExt [255515a4-532d-589b-944b-ec83cf1d0fb0]
# ┌ Warning: Module Makie with build ID ffffffff-ffff-ffff-000f-64a9c18a20b3 is missing from the cache.
# │ This may mean Makie [ee78f7c6-11fb-53f2-987a-cfe4a2b5a57a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing MeasurementsMakieExt [255515a4-532d-589b-944b-ec83cf1d0fb0].
# [ Info: Precompiling DomainSetsMakieExt [da481366-01c8-5b4d-b359-47a10c8532e7]
# ┌ Warning: Module DomainSets with build ID ffffffff-ffff-ffff-000f-64a1aae9e172 is missing from the cache.
# │ This may mean DomainSets [5b8099bc-c8ec-5219-889f-1d9e522a28bf] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing DomainSetsMakieExt [da481366-01c8-5b4d-b359-47a10c8532e7].
# [ Info: Precompiling Cairo [159f3aea-2a34-519c-b102-8c37f9878175]
# ┌ Warning: Module Cairo_jll with build ID ffffffff-ffff-ffff-000f-64b068296520 is missing from the cache.
# │ This may mean Cairo_jll [83423d85-b0ee-5818-9007-b63ccbeb887a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing Cairo [159f3aea-2a34-519c-b102-8c37f9878175].
# [ Info: Precompiling Pango_jll [36c8627f-9965-5494-a995-c6b170f724f3]
# ┌ Warning: Module JLLWrappers with build ID fafbfcfd-fd0a-b190-000f-58855e89d918 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing Pango_jll [36c8627f-9965-5494-a995-c6b170f724f3].
# [ Info: Precompiling BinnedModels [fa1fc709-16e9-4084-816c-4cfb0f07afb9]
# ┌ Warning: Module Distributions with build ID ffffffff-ffff-ffff-000f-648ee4838278 is missing from the cache.
# │ This may mean Distributions [31c24e10-a181-5473-b8eb-7969acd0382f] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1948
# [ Info: Skipping precompilation since __precompile__(false). Importing BinnedModels [fa1fc709-16e9-4084-816c-4cfb0f07afb9].

# %% [markdown]
# ## Step 1: Load the data
#
# The loading step is identical to `ex1_background.jl`: we read the `data_info.csv` index, open the corresponding ROOT files with `UnROOT`, and wrap each tree as a `LazyTree`.

# %%
data_info = CSV.read("/sps/nemo/scratch/mpetro/Sensitivity_training/data/data_info.csv", DataFrame)
file_paths = joinpath.("/sps/nemo/scratch/mpetro/Sensitivity_training/data", data_info.file_name)
data_files = [UnROOT.ROOTFile(file_path) for file_path in file_paths]
tree_name = "tree"
variables = keys(data_files[1][tree_name])
data_tables = [UnROOT.LazyTree(data_file, tree_name, variables) for data_file in data_files]
# Out:
# 5-element Vector{LazyTree with 26 branches:
# sameSide, reconstructedEnergy2, Pext, avgE, z2Reconstructed...
# }:
#  ┌─────┬──────────┬─────────────────┬────────────┬───────────┬───────────────────
# │ Row │ sameSide │ reconstructedEn │ Pext       │ avgE      │ z2Reconstructed  ⋯
# │     │ Float32  │ Float32         │ Float32    │ Float32   │ Float32          ⋯
# ├─────┼──────────┼─────────────────┼────────────┼───────────┼───────────────────
# │ 1   │ 0.0      │ 417.84256       │ 2.062762e- │ 539.3591  │ 36.14118         ⋯
# │ 2   │ 1.0      │ 66.81933        │ 0.4553107  │ 872.25037 │ -62.85587        ⋯
# │ 3   │ 1.0      │ 286.42862       │ 7.6636536e │ 1108.881  │ 796.15796        ⋯
# │ 4   │ 0.0      │ 163.08542       │ 0.00024017 │ 701.16925 │ -1109.882        ⋯
# │ 5   │ 0.0      │ 420.899         │ 5.03516e-1 │ 474.4948  │ -773.49896       ⋯
# │ 6   │ 0.0      │ 771.45776       │ 3.876098e- │ 1004.4069 │ 591.2683         ⋯
# │ 7   │ 0.0      │ 1874.1747       │ 1.8641002e │ 1229.9344 │ 57.884754        ⋯
# │ 8   │ 1.0      │ 529.65607       │ 2.1265148e │ 1056.6787 │ 425.56638        ⋯
# │ 9   │ 1.0      │ 406.13345       │ 3.2517324e │ 392.81482 │ 1084.0039        ⋯
# │ 10  │ 0.0      │ 214.5659        │ 9.306891e- │ 189.38962 │ -1018.7953       ⋯
# │ 11  │ 1.0      │ 1177.3597       │ 1.3748042e │ 981.65796 │ 248.60211        ⋯
# │ 12  │ 1.0      │ 206.56389       │ 2.1849477e │ 963.6602  │ -889.2071        ⋯
# │ 13  │ 1.0      │ 301.16727       │ 1.285089e- │ 355.67328 │ -1038.5955       ⋯
# │ 14  │ 1.0      │ 201.25484       │ 2.5578945e │ 167.68216 │ 779.6068         ⋯
# │ 15  │ 1.0      │ 386.89825       │ 3.3608913e │ 396.52832 │ 517.3048         ⋯
# │ 16  │ 1.0      │ 1254.8173       │ 0.03188491 │ 662.7446  │ 1133.9073        ⋯
# │ 17  │ 1.0      │ 170.93834       │ 0.04334302 │ 427.1207  │ -996.63403       ⋯
# │ 18  │ 1.0      │ 298.3716        │ 2.9213698e │ 731.1632  │ 496.78772        ⋯
# │ 19  │ 0.0      │ 802.2483        │ 6.3770815e │ 735.1224  │ 1218.9833        ⋯
# │ ⋮   │ ⋮        │ ⋮               │ ⋮          │ ⋮         │ ⋮                ⋱
# └─────┴──────────┴─────────────────┴────────────┴───────────┴───────────────────
#                                               21 columns and 275248 rows omitted
#
#  ┌─────┬──────────┬─────────────────┬────────────┬───────────┬───────────────────
# │ Row │ sameSide │ reconstructedEn │ Pext       │ avgE      │ z2Reconstructed  ⋯
# │     │ Float32  │ Float32         │ Float32    │ Float32   │ Float32          ⋯
# ├─────┼──────────┼─────────────────┼────────────┼───────────┼───────────────────
# │ 1   │ 1.0      │ 690.51624       │ 0.59416497 │ 632.05646 │ -1168.6296       ⋯
# │ 2   │ 1.0      │ 1622.456        │ 0.15259245 │ 895.69885 │ -1310.4901       ⋯
# │ 3   │ 0.0      │ 594.45844       │ 0.02044139 │ 1140.0603 │ 1290.1166        ⋯
# │ 4   │ 0.0      │ 108.63111       │ 0.0        │ 308.30185 │ -1028.9381       ⋯
# │ 5   │ 0.0      │ 477.81473       │ 0.03824441 │ 609.8658  │ 31.542788        ⋯
# │ 6   │ 0.0      │ 393.25677       │ 0.00194533 │ 492.07434 │ -1033.6428       ⋯
# │ 7   │ 0.0      │ 216.82806       │ 0.0        │ 345.84558 │ 856.8225         ⋯
# │ 8   │ 1.0      │ 1525.9146       │ 0.01227431 │ 819.435   │ -812.8845        ⋯
# │ 9   │ 0.0      │ 390.9029        │ 1.1784849e │ 696.53357 │ -1247.1968       ⋯
# │ 10  │ 0.0      │ 791.47473       │ 1.8668312e │ 550.1555  │ -652.8579        ⋯
# │ 11  │ 0.0      │ 337.6661        │ 0.02482531 │ 370.1036  │ -105.51745       ⋯
# │ 12  │ 0.0      │ 572.73914       │ 0.00265795 │ 620.58984 │ -611.84204       ⋯
# │ 13  │ 1.0      │ 191.93724       │ 6.205178e- │ 412.8963  │ -1285.9303       ⋯
# │ 14  │ 0.0      │ 314.6413        │ 0.00667476 │ 625.0333  │ -395.97528       ⋯
# │ 15  │ 0.0      │ 1329.3944       │ 0.0        │ 783.91    │ -914.7236        ⋯
# │ 16  │ 0.0      │ 199.11046       │ 0.0        │ 342.49356 │ -849.72345       ⋯
# │ 17  │ 0.0      │ 723.9024        │ 2.4744215e │ 841.384   │ 277.6765         ⋯
# │ 18  │ 0.0      │ 574.81995       │ 0.19368836 │ 558.3518  │ -462.26804       ⋯
# │ 19  │ 0.0      │ 542.37006       │ 0.06978784 │ 448.242   │ 1204.41          ⋯
# │ ⋮   │ ⋮        │ ⋮               │ ⋮          │ ⋮         │ ⋮                ⋱
# └─────┴──────────┴─────────────────┴────────────┴───────────┴───────────────────
#                                               21 columns and 176868 rows omitted
#
#  ┌─────┬──────────┬─────────────────┬────────────┬───────────┬───────────────────
# │ Row │ sameSide │ reconstructedEn │ Pext       │ avgE      │ z2Reconstructed  ⋯
# │     │ Float32  │ Float32         │ Float32    │ Float32   │ Float32          ⋯
# ├─────┼──────────┼─────────────────┼────────────┼───────────┼───────────────────
# │ 1   │ 0.0      │ 429.4168        │ 5.3827105e │ 483.92172 │ 510.26352        ⋯
# │ 2   │ 0.0      │ 1034.3418       │ 7.1497943e │ 669.03235 │ -1054.9557       ⋯
# │ 3   │ 0.0      │ 498.30295       │ 8.4202645e │ 420.53674 │ 262.8271         ⋯
# │ 4   │ 1.0      │ 471.04285       │ 8.597589e- │ 572.0669  │ -1023.178        ⋯
# │ 5   │ 1.0      │ 204.13478       │ 1.9421113e │ 403.82004 │ 962.1402         ⋯
# │ 6   │ 1.0      │ 265.529         │ 4.7955043e │ 475.8964  │ 282.32523        ⋯
# │ 7   │ 1.0      │ 775.6324        │ 5.118418e- │ 558.76855 │ 239.86427        ⋯
# │ 8   │ 0.0      │ 630.5003        │ 5.0634e-7  │ 527.86224 │ -566.0846        ⋯
# │ 9   │ 1.0      │ 368.18857       │ 0.00033034 │ 493.90442 │ 890.62146        ⋯
# │ 10  │ 0.0      │ 236.69955       │ 0.00662634 │ 376.05054 │ 350.8573         ⋯
# │ 11  │ 1.0      │ 368.82693       │ 7.636536e- │ 277.49298 │ -183.02979       ⋯
# │ 12  │ 0.0      │ 468.10825       │ 5.3535728e │ 580.88965 │ -12.263001       ⋯
# │ 13  │ 0.0      │ 529.8707        │ 2.5501862e │ 705.21564 │ 519.7841         ⋯
# │ 14  │ 0.0      │ 579.0121        │ 3.447444e- │ 462.61554 │ -432.7027        ⋯
# │ 15  │ 0.0      │ 893.1515        │ 1.4576504e │ 792.8657  │ -338.6269        ⋯
# │ 16  │ 0.0      │ 605.52875       │ 8.792518e- │ 703.3014  │ -871.98          ⋯
# │ 17  │ 0.0      │ 382.19373       │ 5.166619e- │ 483.69717 │ -797.4429        ⋯
# │ 18  │ 0.0      │ 353.60248       │ 5.54992e-9 │ 548.87506 │ -1179.931        ⋯
# │ 19  │ 1.0      │ 466.53616       │ 0.00102909 │ 349.19308 │ 872.718          ⋯
# │ ⋮   │ ⋮        │ ⋮               │ ⋮          │ ⋮         │ ⋮                ⋱
# └─────┴──────────┴─────────────────┴────────────┴───────────┴───────────────────
#                                               21 columns and 181924 rows omitted
#
#  ┌─────┬──────────┬─────────────────┬────────────┬───────────┬───────────────────
# │ Row │ sameSide │ reconstructedEn │ Pext       │ avgE      │ z2Reconstructed  ⋯
# │     │ Float32  │ Float32         │ Float32    │ Float32   │ Float32          ⋯
# ├─────┼──────────┼─────────────────┼────────────┼───────────┼───────────────────
# │ 1   │ 0.0      │ 689.11017       │ 1.0325101e │ 1410.0713 │ -545.16455       ⋯
# │ 2   │ 0.0      │ 730.2764        │ 4.3091843e │ 1392.3158 │ -419.4327        ⋯
# │ 3   │ 1.0      │ 219.16035       │ 7.065073e- │ 1427.318  │ 888.78644        ⋯
# │ 4   │ 1.0      │ 492.73914       │ 7.470687e- │ 1348.5796 │ -1336.5371       ⋯
# │ 5   │ 0.0      │ 2033.8278       │ 0.0        │ 1331.49   │ 93.62686         ⋯
# │ 6   │ 0.0      │ 505.87695       │ 1.8588082e │ 1428.9006 │ -1133.7592       ⋯
# │ 7   │ 1.0      │ 444.85312       │ 7.9466946e │ 730.9646  │ -1295.3976       ⋯
# │ 8   │ 0.0      │ 1896.322        │ 1.4437136e │ 1312.2739 │ 308.39203        ⋯
# │ 9   │ 0.0      │ 685.58795       │ 8.028798e- │ 1328.569  │ 998.2242         ⋯
# │ 10  │ 0.0      │ 172.32649       │ 0.00048117 │ 1229.273  │ 853.8652         ⋯
# │ 11  │ 0.0      │ 1937.1322       │ 8.290566e- │ 1342.4713 │ 279.77908        ⋯
# │ 12  │ 1.0      │ 226.61516       │ 1.2125162e │ 1341.4644 │ -521.27765       ⋯
# │ 13  │ 1.0      │ 440.9702        │ 4.4689107e │ 1171.0714 │ -406.85675       ⋯
# │ 14  │ 0.0      │ 1227.2677       │ 1.2371603e │ 1418.2529 │ -684.2786        ⋯
# │ 15  │ 0.0      │ 1380.1965       │ 4.6210826e │ 1448.3671 │ 398.4395         ⋯
# │ 16  │ 0.0      │ 2038.6294       │ 0.2606633  │ 1387.7775 │ 1194.0178        ⋯
# │ 17  │ 1.0      │ 2107.7852       │ 0.0        │ 1426.9854 │ -463.54074       ⋯
# │ 18  │ 1.0      │ 571.38916       │ 5.0449946e │ 1428.2164 │ 1070.6226        ⋯
# │ 19  │ 1.0      │ 1196.5065       │ 0.0        │ 1361.9045 │ 246.40724        ⋯
# │ ⋮   │ ⋮        │ ⋮               │ ⋮          │ ⋮         │ ⋮                ⋱
# └─────┴──────────┴─────────────────┴────────────┴───────────┴───────────────────
#                                              21 columns and 3682764 rows omitted
#
#  ┌─────┬──────────┬─────────────────┬────────────┬───────────┬───────────────────
# │ Row │ sameSide │ reconstructedEn │ Pext       │ avgE      │ z2Reconstructed  ⋯
# │     │ Float32  │ Float32         │ Float32    │ Float32   │ Float32          ⋯
# ├─────┼──────────┼─────────────────┼────────────┼───────────┼───────────────────
# │ 1   │ 0.0      │ 261.6549        │ 9.348422e- │ 787.9614  │ -401.48032       ⋯
# │ 2   │ 0.0      │ 1509.1617       │ 0.02930915 │ 919.0187  │ -30.146044       ⋯
# │ 3   │ 0.0      │ 1103.0204       │ 0.00048962 │ 638.8428  │ 958.42175        ⋯
# │ 4   │ 0.0      │ 425.72037       │ 1.4389564e │ 483.26355 │ 276.30167        ⋯
# │ 5   │ 0.0      │ 359.85916       │ 0.00028110 │ 544.3812  │ -666.0835        ⋯
# │ 6   │ 1.0      │ 323.68146       │ 2.0957367e │ 424.60938 │ -42.522575       ⋯
# │ 7   │ 0.0      │ 543.0998        │ 0.62598956 │ 326.344   │ 1082.4957        ⋯
# │ 8   │ 1.0      │ 1152.7703       │ 0.00016365 │ 737.4912  │ -107.02444       ⋯
# │ 9   │ 1.0      │ 984.82935       │ 6.746892e- │ 701.69934 │ 1171.2649        ⋯
# │ 10  │ 1.0      │ 1296.5591       │ 0.00400609 │ 901.5199  │ -545.44977       ⋯
# │ 11  │ 1.0      │ 252.96284       │ 0.31139842 │ 335.11862 │ -764.49243       ⋯
# │ 12  │ 0.0      │ 737.2052        │ 1.5687875e │ 593.28284 │ -470.94446       ⋯
# │ 13  │ 0.0      │ 146.90298       │ 0.00128238 │ 641.9061  │ -1166.7451       ⋯
# │ 14  │ 1.0      │ 708.4975        │ 5.508532e- │ 819.72095 │ -841.9604        ⋯
# │ 15  │ 0.0      │ 589.53986       │ 8.78536e-8 │ 441.72583 │ 698.5396         ⋯
# │ 16  │ 1.0      │ 1383.6335       │ 1.7922672e │ 801.00494 │ 681.0082         ⋯
# │ 17  │ 0.0      │ 702.75793       │ 9.353198e- │ 829.9424  │ -955.0287        ⋯
# │ 18  │ 1.0      │ 113.60928       │ 0.01779238 │ 399.9981  │ 422.99844        ⋯
# │ 19  │ 0.0      │ 862.1126        │ 2.4949825e │ 944.4263  │ -10.429228       ⋯
# │ ⋮   │ ⋮        │ ⋮               │ ⋮          │ ⋮         │ ⋮                ⋱
# └─────┴──────────┴─────────────────┴────────────┴───────────┴───────────────────
#                                             21 columns and 15116876 rows omitted

# %% [markdown]
# ### Step 1.1: Apply data cuts
#
# In `ex1` we did not impose any cuts on the data. For a sensitivity estimate to be meaningful, we first need to restrict the data to a region where signal-like events are enriched relative to background — this is the same selection logic used in any counting-experiment analysis.
#
# We'll cut on:
# - `sumE` — the total reconstructed energy of the event,
# - `dy`, `dz` — vertex distance in y and z direction (in mm),
# - `Pint`, `Pext` — internal/external probability
#
# First we define which variables we want to cut on:

# %%
var_names = [ 
    "sumE", 
    "dy", 
    "dz",
    "Pint",
    "Pext",
    ]

# %% [markdown]
# Next we define the bounds of each cut. Here we use a simple selection: `sumE` > 300 keV, `dy` < 100 mm, `dz` < 100 mm, `Pint` > 0.01, `Pext` < 0.01 — i.e. events with enough energy, a vertex match, and a topology favoring an internal-decay hypothesis.

# %%
var_bounds = (
    sumE = (300, 3500),
    dy = (0, 100),
    dz = (0, 100),
    Pint = (0.01, 1),
    Pext = (0, 0.01),
)

# %% [markdown]
# Now we apply the cuts with `SNSensitivityEstimate.filter_data`, which filters each table according to `var_names` and `var_bounds` before we load it into a `DataProcess`:

# %%
filtered_data_tables = [SNSensitivityEstimate.filter_data(table, var_names, var_bounds) for table in data_tables]

# %% [markdown]
# As before, we wrap each filtered table into a `SNSensitivityEstimate.DataProcess` object — this time using the cut data instead of the raw data:

# %%
processes = [
    SNSensitivityEstimate.DataProcess(
        collect(filtered_data_tables[i].sumE), # Here we specify a single variable to be used. In later stages we will use N-dimensional data vectors.
        String(data_info.process[i]),
        data_info.is_signal[i],
        data_info.activity[i],
        data_info.time_s[i],
        data_info.n_sim[i],
        0:100:3500,
        data_info.amount[i],
    ) for i in 1:length(filtered_data_tables)
]

# %% [markdown]
# > **Optional exercise:** redo the `ex1_background.jl` example with these cuts applied (or try your own cuts) and see how the expected background spectrum changes.

# %% [markdown]
# ## Step 2: Build normalized signal and background histograms
#
# The Bayesian fit doesn't operate on raw event counts directly — it needs **shape templates** (normalized histograms) for signal and background, plus a **pseudo-dataset** to fit them to. We build all three in this step.

# %% [markdown]
# First, we separate out the signal process (`bb0nu_foil_bulk`, the neutrinoless double-beta decay signal) and obtain its histogram:

# %%
signal = SNSensitivityEstimate.get_process("bb0nu_foil_bulk", processes)[1]
signal_hist = SNSensitivityEstimate.get_bkg_counts_1D(signal)

# %% [markdown]
# Then we collect all the remaining (background) processes and get their histograms too:

# %%
bkg_names = [ p.isotopeName for p in processes if !p.signal ]
background = [SNSensitivityEstimate.get_process(name, processes)[1] for name in bkg_names]
bkg_hist = [SNSensitivityEstimate.get_bkg_counts_1D(p) for p in background]

# %% [markdown]
# For the fit, the templates need to be **shape-only** (i.e. probability densities, not raw expected counts), so we normalize each histogram by its bin widths:

# %%
bkg_hist_normed = FHist.normalize.(bkg_hist, width = true)
signal_hist_normed = FHist.normalize(signal_hist, width = true)

# %% [raw]
# ### Step 2.1: Build a pseudo-data histogram
#
# Since we don't have real data here (working on simulated data-set for now), we generate a **pseudo-experiment**: we sample each background histogram bin-by-bin from a Poisson distribution with mean equal to the expected count in that bin (`SNSensitivityEstimate.get_pseudo_spectrum`), then merge all the sampled background processes into one combined "observed" spectrum. This mimics what a real measured spectrum would look like if there were *no* signal present — letting us later check how sensitive the fit is to a hypothetical signal on top of pure background.

# %%
sample_hists = [SNSensitivityEstimate.get_pseudo_spectrum(b) for b in bkg_hist] 
# merge them together into a single pseudo-experiment
data_hist = merge(sample_hists...)

# %% [markdown]
# Let's compare the pseudo-data against the underlying background model, to sanity-check that the sampling looks reasonable:

# %%
let
    f = CairoMakie.Figure(size = (800, 600))
    a = CairoMakie.Axis(f[1, 1], title = "Pseudo-data vs background model", xlabel = "sum of energies", ylabel = "counts")
    CairoMakie.stephist!(a, sum(bkg_hist), label = "background model", color = :red)
    CairoMakie.stephist!(a, data_hist, label = "pseudo-data", color = :blue)
    CairoMakie.axislegend(a, position = :lt)
    f
end

# %% [markdown]
# ## Step 3: Define the Bayesian model
#
# With our pseudo-data and templates ready, we now set up the Bayesian inference problem. In Bayesian statistics this means specifying three ingredients: a **prior** (what we assume before seeing the data), a **likelihood** (how probable the data are given the model parameters), and the resulting **posterior** (what we believe about the parameters after seeing the data).

# %% [markdown]
# ### Step 3.1: Prior
#
# We use an *uninformed* (flat) prior for each process's relative activity — i.e. we don't favor any particular value ahead of time. `As` is the signal amplitude, `Ab` is a vector of amplitudes, one per background process:

# %%
prior = ValueShapes.NamedTupleDist(
    As = Distributions.Uniform(1e-20, 1), # one prior for signal - flat prior between 0 and 1
    Ab = [Distributions.Uniform(1e-20,1) for _ in 1:length(bkg_hist)] # same with background priors
)

# %% [markdown]
# ### Step 3.2: Likelihood
#
# The likelihood is built from the normalized signal/background histograms. It is defined in section 5.4.3 of the accompanying PhD thesis (will be uploaded to docDB when available). Conceptually: the fit parameters are the *relative weights* of each process's contribution to the total pseudo-data histogram —
#
# - `A_s` — relative amount of signal,
# - `A_b` — vector of relative amounts of each background process —
#
# and the likelihood tells us how probable the observed `data_hist` is for a given choice of these weights.

# %%
likelihood = SNSensitivityEstimate.make_hist_likelihood_uniform(
    data_hist,
    signal_hist_normed,
    bkg_hist_normed
)

# %% [markdown]
# ### Step 3.3: Posterior
#
# `BAT.jl` provides a convenient interface to combine prior and likelihood into a posterior: we simply call `BAT.PosteriorMeasure` with both as arguments.

# %%
posterior = BAT.PosteriorMeasure(likelihood, prior)

# %% [markdown]
# ### Step 3.4: MCMC sampler setup
#
# To actually explore the posterior distribution, we use Markov Chain Monte Carlo (MCMC) sampling, as implemented in `BAT.jl` (full documentation at [bat.github.io/BAT.jl/stable](https://bat.github.io/BAT.jl/stable/)). Here we just configure some sensible defaults:
#
# - `burnin` — settings for the *burn-in* phase, where the chain is allowed to wander before we start collecting samples, so it can "forget" its (possibly poor) starting point,
# - `mcmcalgo` — the sampling algorithm itself; we use a simple random-walk Metropolis sampler.

# %%
burnin = BAT.MCMCMultiCycleBurnin(max_ncycles = 30, nsteps_final=1000)
mcmcalgo = BAT.RandomWalk()

# %% [markdown]
# ## Step 4: Run the MCMC sampling
#
# We now actually run the sampler. `nsteps` is the number of MCMC steps per chain, and `nchains` is the number of independent chains run in parallel (running multiple chains lets us check that they all converge to the same posterior, as a consistency check).
#
# > This step is computationally the heaviest part of the notebook and may take a little while to run.

# %%
samples, _ = BAT.bat_sample( posterior, BAT.MCMCSampling(mcalg = mcmcalgo, burnin = burnin, nsteps = 10_000, nchains = 4))

# %% [markdown]
# We can print some basic summary statistics of the posterior samples — the mode (most likely value), mean, and standard deviation for each fitted parameter:

# %%
println("Mode: $(mode(samples))")
println("Mean: $(mean(samples))")
println("Stddev: $(std(samples))")

# %%
binned_unshaped_samples, _ = BAT.bat_transform(Vector, samples)

# %% [markdown]
# Now we can look at the posterior distribution of each individual parameter — i.e. how tightly constrained the signal amplitude and each background amplitude are by the fit — by histogramming the MCMC samples for each one:

# %%
let
    f = CairoMakie.Figure(size = (800, 1000))
    a1 = CairoMakie.Axis(f[1, 1], title = "Posterior distribution of signal", xlabel = "signal ratio", ylabel = "counts")
    d = [par[1] for par in binned_unshaped_samples.v]
    h = FHist.Hist1D(d; binedges= range(0, maximum(d), length = 100))
    CairoMakie.stephist!(a1, h, label = "A_s", color = :blue)
    CairoMakie.axislegend(a1, position = :ct)

    labels = data_info.process[.!data_info.is_signal]
    colors = Makie.wong_colors()
    for i in 1:length(bkg_hist)
        a2 = CairoMakie.Axis(f[i+1, 1], title = "Posterior distribution of $(labels[i])", xlabel = "background ratio", ylabel = "counts")       
        d = [par[i+1] for par in binned_unshaped_samples.v]
        h = FHist.Hist1D(d; binedges= range(0, maximum(d), length = 100))
        CairoMakie.stephist!(a2, h, label = "A_b$(i)", color = colors[i])
        CairoMakie.axislegend(a2, position = :ct)
    end
    save("data/out/ex2/posterior_distributions.png", f, px_per_unit = 2)
    f
end

# %% [markdown]
# ## Step 5: Convert the posterior into a sensitivity
#
# We now turn the posterior distribution of the signal amplitude into a physical **sensitivity** — i.e. the half-life that this (pseudo-)experiment is sensitive to.
#
# The convention used here is the standard "90% credible interval" sensitivity: we take the **90% quantile** of the posterior distribution of the signal amplitude as the upper limit on the number of signal events the data are consistent with, given no significant excess was found. This is then converted into a half-life via:
#
# $$T_{1/2} = \ln(2) \cdot \frac{N_A \, m \, t \, \varepsilon}{W \cdot \mu_{S}^{90}}$$
#
# where:
# - $N_A$ is Avogadro's number,
# - $m$ is the mass of the isotope of interest,
# - $t$ is the live-time of the experiment,
# - $\varepsilon$ is the signal detection efficiency in the chosen region of interest (ROI),
# - $W$ is the molar mass of the isotope,
# - $\mu_S^{90}$ is the 90% credible-interval upper limit on the expected number of signal events, obtained from the posterior.

# %%
nDataPoints = integral(data_hist)
muS = [par[1] for par in binned_unshaped_samples.v]
exp_mu_signal_90 = BAT.smallest_credible_intervals(muS, nsigma_equivalent=1.65)[1].right * nDataPoints # this gives the smallest credible interval

Na = SNparams["Nₐ"]
m = SNparams["foilMass"] * SNparams["a"]
t = SNparams["tYear"]
W = SNparams["W"]

ROI_a, ROI_b = 300, 3500-50
eff = lookup(signal, ROI_a, ROI_b) 
t12 = log(2) * (Na * m * t * eff / W) / exp_mu_signal_90

# %%
println("Sensitivity (90% CI) in terms of half-life: $(t12) years)")
println("for a signal efficiency of $(eff)")
println("in the ROI of $(ROI_a) to $(ROI_b) keV.")
println("equivalent to an expected number of signal events of $(round(exp_mu_signal_90, digits= 3))")

# %% [markdown]
# ## (Optional) Step 6: Visualize the fit result
#
# As a sanity check, let's plot the fitted spectrum — built from the posterior mean amplitudes of each process — against the pseudo-background, to see how well the fit reproduces the input shapes.

# %%
amps = mean(samples) # get the amplitudes of each process from the posterior samples, which are the mean of the samples for each parameter.

# %%
let 
    colors = Makie.wong_colors()
    bkg_amps = amps[2] ./ sum(amps[2]) # normalize the background amplitudes to sum to 1
    labels = data_info.process[.!data_info.is_signal]
    f = Figure(size = (1200,800), fontsize = 26)
    a = Axis(f[1,1], xlabel = "sum E", ylabel = "Counts / 17.5kg.yr", title = "Fitted spectrum of a single pseudo-experiment", limits = (300,3500, 0, nothing) )
    h_total = sum(bkg_hist)
    n_total = integral(h_total)
    CairoMakie.stephist!(a, h_total, color = :black, label = "Total pseudo-background", linewidth = 4)
    
    h_fit = [ a*normalize(h, width = false)*n_total for (h, a) in zip(bkg_hist, bkg_amps)]

    for i in 1:length(h_fit[1:end])
        CairoMakie.stephist!(a, h_fit[i], color = colors[i], label = labels[i], linewidth = 4)
    end
    CairoMakie.hist!(a, sum(h_fit), label = "Fitted total", color = (colors[1], 0.4), )
    
    axislegend(a; position = :rt, patchsize = (45,35), labelsize = 20)
    save("data/out/ex2/fit_result.png", f, px_per_unit = 2)
    f
end

# %% [markdown]
# ## (For later) Step 7: From a single pseudo-experiment to a robust sensitivity
#
# The procedure above gives the sensitivity for a **single** pseudo-experiment. But MCMC sampling — and the Poisson-sampling of the pseudo-data itself — is a *stochastic* process: running it again with a different random seed will give a somewhat different answer. A sensitivity quoted from just one pseudo-experiment is therefore not representative of the true sensitivity of the experiment.
#
# To obtain a robust number suitable for publication, we repeat the *entire* pipeline — generate new pseudo-data, run a fresh MCMC fit, compute a new sensitivity — many times, and report the **median** of the resulting sensitivity distribution. This whole loop is encapsulated by `SNSensitivityEstimate.get_sens_bayes_uniform`, which performs one full pseudo-experiment (sampling + fit + sensitivity calculation) per call.
#
# > This will take a while, since each iteration involves a full MCMC run — `n_max` is kept small (10) here for demonstration purposes; in practice you would use a much larger number of pseudo-experiments to get a stable median.

# %%
t_halfs = []
n_max = 10 # number of pseudo-experiments to run
for i in 1:n_max

    try 
        println("Running pseudo-experiment $(i) of $(n_max)")
        sens = SNSensitivityEstimate.get_sens_bayes_uniform(
            bkg_hist, 
            signal, 
            prior; 
            ROI_a = ROI_a, ROI_b = ROI_b, nsteps = 5*10^4, nchains = 4)
        println(sens)
        push!(t_halfs, sens)
    catch
        @warn "failed fit" 
        continue
    end
end

# %% [markdown]
# Finally, let's plot the distribution of sensitivities obtained across all pseudo-experiments, and mark the median value — this median is the number we would actually quote as "the" sensitivity of the experiment.

# %%
let
    f = CairoMakie.Figure(size = (800, 600))
    a = CairoMakie.Axis(f[1, 1], title = "Distribution of sensitivities from $(n_max) pseudo-experiments", xlabel = "sensitivity (years)", ylabel = "counts")
    h = FHist.Hist1D(t_halfs; binedges= range(0, maximum(t_halfs), length = n_max))
    CairoMakie.stephist!(a, h, label = "sensitivity distribution", color = :blue)

    median_sens = StatsBase.median(t_halfs)
    CairoMakie.vlines!(a, [median_sens], color = :red, label = "median sensitivity: $(round(median_sens, sigdigits= 3)) years")
    CairoMakie.axislegend(a, position = :ct)
    save("data/out/ex2/sensitivity_distribution.png", f, px_per_unit = 2)
    f
end
